# %%
import helper
import pickle

# %%
tifs = helper.read_all_tifs(positive_strand_only=True, return_dict=True)

# %%
genome = helper.organize_genome_by_chrom(helper.read_bedfile(), positive_strand_only=True)

# %%
densities = pickle.load(open("densities.pickle", "rb"))
for chrom in helper.kYeastChroms:
    densities[chrom] = densities[chrom][0]

# %%
import matplotlib.pyplot as plt
import numpy as np
import matplotlib

save_to_pgf=True

np.random.seed(1135)

# %%
if save_to_pgf: 
    matplotlib.use("pgf")
    matplotlib.rcParams.update({
        "pgf.texsystem": "pdflatex",
        'font.family': 'serif',
        'text.usetex': True,
        'pgf.rcfonts': False,
    })
else:
    matplotlib.rcdefaults()

# %%
from metagene_helper import select_one_random_junction, kJunctionCandidates
# Out:
# INFO:helper:Reading bedfile...
# INFO:helper:Done reading bedfile ../indexes/yeast-all.bed
# INFO:helper:Processed TIFs in chromosome 1...
# INFO:helper:Processed TIFs in chromosome 2...
# INFO:helper:Processed TIFs in chromosome 3...
# INFO:helper:Processed TIFs in chromosome 4...
# INFO:helper:Processed TIFs in chromosome 5...
# INFO:helper:Processed TIFs in chromosome 6...
# INFO:helper:Processed TIFs in chromosome 7...
# INFO:helper:Processed TIFs in chromosome 8...
# INFO:helper:Processed TIFs in chromosome 9...
# INFO:helper:Processed TIFs in chromosome 10...
# INFO:helper:Processed TIFs in chromosome 11...
# INFO:helper:Processed TIFs in chromosome 12...
# INFO:helper:Processed TIFs in chromosome 13...
# INFO:helper:Processed TIFs in chromosome 14...
# INFO:helper:Processed TIFs in chromosome 15...
# INFO:helper:Processed TIFs in chromosome 16...
# INFO:helper:Done reading TIF file... returning a dictionary

# %%
n = 100

# %%
unsorted_tifs = helper.read_all_tifs()
# Out:
# INFO:helper:Done reading TIF file... returning a pandas

# %%
def get_all_junctions_chrom(chrom, tifs):
    splits = []
    for gene, gtifs in tifs[chrom].items():
        junctions = helper.generate_5utr_isoform_starts(gtifs)
        splits = splits + junctions[1:]
    return splits

# %%
big_meta = [0] * (2 * n)
fake_meta = [0] * (2 * n)

bad_meta = [0] * (2 * n)
bad_random_meta = [0] * (2 * n)


np.random.seed(1135)

for chrom in helper.kYeastChroms:
    splits = select_one_random_junction(chrom, tifs)
    meta = helper.make_metagene_plot((densities[chrom], []),
                                     splits,
                                     "",
                                     n,
                                     n,
                                     plot=False)
    big_meta = np.add(big_meta, meta)

    fake_junctions = [(x, "+") for x in np.random.choice(
        kJunctionCandidates[chrom],
        size=len(splits),
        replace=False)]
    meta = helper.make_metagene_plot((densities[chrom], []),
                                     fake_junctions,
                                     "",
                                     n,
                                     n,
                                     plot=False)
    fake_meta = np.add(fake_meta, meta)
    
    all_junctions = get_all_junctions_chrom(chrom, tifs)
    meta = helper.make_metagene_plot((densities[chrom], []),
                                     all_junctions,
                                     "",
                                     n,
                                     n,
                                     plot=False)
    bad_meta = np.add(bad_meta, meta)
    
    fake_junctions = [(x, "+") for x in np.random.choice(
        kJunctionCandidates[chrom],
        size=len(all_junctions),
        replace=False)]
    meta = helper.make_metagene_plot((densities[chrom], []),
                                     fake_junctions,
                                     "",
                                     n,
                                     n,
                                     plot=False)
    bad_random_meta = np.add(bad_random_meta, meta)
# Out:
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 44
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(143657, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 44
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(33419, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 1184
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(143602, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 1184
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(183721, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 171
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(236353, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 171
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(270212, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5884
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(236325, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5884
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(549350, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 51
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(111897, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 51
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(70110, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 1798
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(111285, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 1798
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(111526, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 342
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(447984, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 342
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(139478, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 13103
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(447875, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 13103
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(861840, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 136
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(148130, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 136
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(302640, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5265
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(146962, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5265
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(131624, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 49
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(147093, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 49
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(246036, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 1650
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(146994, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 1650
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(95880, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 254
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(494443, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 254
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(81262, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 8309
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(494396, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 8309
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(438287, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 135
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(104223, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 135
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(489491, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 4290
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(104178, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 4290
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(493863, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 89
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(353875, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 89
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(177104, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 2625
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(353636, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 2625
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(338867, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 163
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(435124, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 163
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(639818, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5367
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(434915, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5367
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(116788, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 156
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(437745, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 156
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(402146, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5328
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(437300, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5328
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(571485, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 212
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(147834, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 212
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(340150, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 6974
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(147811, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 6974
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(853393, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 215
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(267083, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 215
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(110995, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 8075
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(266923, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 8075
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(306579, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 193
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(627431, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 193
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(676125, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5981
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(627376, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 5981
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(526066, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 254
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(325140, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 254
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(1058282, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 8174
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(324805, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 8174
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(1056548, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 231
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(554589, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 231
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(610439, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 7790
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(554549, '+')
# INFO:helper:Generating metagene plot... Number of overlapping sites is: 7790
# INFO:helper:<class 'tuple'>
# INFO:helper:type of splits[0] is <class 'tuple'>
# INFO:helper:(468751, '+')

# %%
plt.plot(range(-n, n), big_meta)    
plt.title("Metagene plot of non-overlaping ioform positions")
plt.xlabel("Distance from junction (nt)")
plt.ylabel("Aggregated Read density")
plt.savefig("final_plots/good_metagene.pgf")

plt.close()

# %%
plt.plot(range(-n, n), fake_meta)    
plt.title("Metagene plot of non-overlaping random positions")
plt.xlabel("Distance from junction (nt)")
plt.ylabel("Aggregated Read density")
plt.savefig("final_plots/random_metagene.pgf")

plt.close()

# %%
plt.plot(range(-50, 50), bad_meta[50:150])    
plt.title("Metagene plot of all ioform positions")
plt.xlabel("Distance from junction (nt)")
plt.ylabel("Aggregated Read density")
plt.savefig("final_plots/all_metagene.pgf")

plt.close()

# %%
plt.plot(range(-50, 50), bad_random_meta[50:150])    
plt.title("Metagene plot of random genomic positions")
plt.xlabel("Distance from junction (nt)")
plt.ylabel("Aggregated Read density")
plt.savefig("final_plots/random_big_metagene.pgf")

plt.close()
